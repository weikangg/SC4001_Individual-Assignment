# %% [markdown]
# CS4001/4042 Assignment 1, Part B, Q1
# ---
#
# Real world datasets often have a mix of numeric and categorical features – this dataset is one example. To build models on such data, categorical features have to be encoded or embedded.
#
# PyTorch Tabular is a library that makes it very convenient to build neural networks for tabular data. It is built on top of PyTorch Lightning, which abstracts away boilerplate model training code and makes it easy to integrate other tools, e.g. TensorBoard for experiment tracking.
#
# For questions B1 and B2, the following features should be used:
# - **Numeric / Continuous** features: dist_to_nearest_stn, dist_to_dhoby, degree_centrality, eigenvector_centrality, remaining_lease_years, floor_area_sqm
# - **Categorical** features: month, town, flat_model_type, storey_range

# %% [markdown]
# ---

# %%
# %pip install pytorch_tabular[extra]
# Out:
# Requirement already satisfied: pytorch_tabular[extra] in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (1.0.2)
# Requirement already satisfied: tensorboard!=2.5.0,>2.2.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (2.14.0)
# Requirement already satisfied: protobuf<4.23.0,>=3.20.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (4.22.5)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (1.24.4)
# Requirement already satisfied: torch>=1.9.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (1.13.1)
# Requirement already satisfied: rich>=11.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (13.5.3)
# Requirement already satisfied: matplotlib>3.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (3.8.0)
# Requirement already satisfied: torchmetrics<0.12.0,>=0.10.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (0.11.4)
# Requirement already satisfied: PyYAML<6.1.0,>=5.4 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (6.0.1)
# Requirement already satisfied: ipywidgets in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (8.1.1)
# Requirement already satisfied: category-encoders<2.7.0,>=2.6.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (2.6.2)
# Requirement already satisfied: pytorch-lightning<2.0.0,>=1.8.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (1.9.5)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (2.1.1)
# Requirement already satisfied: omegaconf>=2.1.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (2.3.0)
# Requirement already satisfied: einops<0.7.0,>=0.6.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (0.6.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: pytorch-tabnet==4.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (4.0)
# Requirement already satisfied: kaleido==0.2.* in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (0.2.1)
# Requirement already satisfied: wandb==0.13.* in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (0.13.11)
# Requirement already satisfied: plotly<5.15.0,>=5.13.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch_tabular[extra]) (5.14.1)
# Requirement already satisfied: tqdm<5.0,>=4.36 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch-tabnet==4.0->pytorch_tabular[extra]) (4.66.1)
# Requirement already satisfied: scipy>1.4 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch-tabnet==4.0->pytorch_tabular[extra]) (1.11.2)
# Requirement already satisfied: pathtools in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (0.1.2)
# Requirement already satisfied: typing-extensions in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (4.8.0)
# Requirement already satisfied: setuptools in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (58.1.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (3.1.37)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (2.31.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (8.1.7)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (1.4.4)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (1.31.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (0.4.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (5.9.5)
# Requirement already satisfied: setproctitle in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from wandb==0.13.*->pytorch_tabular[extra]) (1.3.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from category-encoders<2.7.0,>=2.6.0->pytorch_tabular[extra]) (0.14.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from category-encoders<2.7.0,>=2.6.0->pytorch_tabular[extra]) (0.5.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (6.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (4.42.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.1.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (0.11.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from omegaconf>=2.1.0->pytorch_tabular[extra]) (4.9.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from plotly<5.15.0,>=5.13.0->pytorch_tabular[extra]) (8.2.3)
# Requirement already satisfied: fsspec[http]>2021.06.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (2023.9.2)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (0.9.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (3.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=1.0.0->pytorch_tabular[extra]) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=1.0.0->pytorch_tabular[extra]) (1.3.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.23.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.58.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.4.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.41.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.7.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipywidgets->pytorch_tabular[extra]) (5.10.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (4.0.9)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipywidgets->pytorch_tabular[extra]) (8.15.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipywidgets->pytorch_tabular[extra]) (0.1.4)
# Requirement already satisfied: colorama in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from Click!=8.0.0,>=7.0->wandb==0.13.*->pytorch_tabular[extra]) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from docker-pycreds>=0.4.0->wandb==0.13.*->pytorch_tabular[extra]) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (3.8.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.13.*->pytorch_tabular[extra]) (4.0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.26.16)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib>3.1->pytorch_tabular[extra]) (3.17.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (3.0.39)
# Requirement already satisfied: exceptiongroup in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (1.1.3)
# Requirement already satisfied: pickleshare in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.7.5)
# Requirement already satisfied: backcall in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.6.2)
# Requirement already satisfied: matplotlib-inline in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.19.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (6.8.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->pytorch_tabular[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.0.0->wandb==0.13.*->pytorch_tabular[extra]) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.1.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.8.0->pytorch_tabular[extra]) (4.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.13.*->pytorch_tabular[extra]) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\wei kang\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.2.2)
# Requirement already satisfied: pure-eval in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\wei kang\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\Wei Kang\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
SEED = 42

import random
random.seed(SEED)
import math
import warnings

import numpy as np
np.random.seed(SEED)

import pandas as pd
from sklearn.metrics import r2_score

from pytorch_tabular import TabularModel
from pytorch_tabular.models import CategoryEmbeddingModelConfig
from pytorch_tabular.config import (
    DataConfig,
    OptimizerConfig,
    TrainerConfig,
)

# %% [markdown]
# > Divide the dataset (‘hdb_price_prediction.csv’) into train, validation and test sets by using entries from year 2019 and before as training data, year 2020 as validation data and year 2021 as test data.
# **Do not** use data from year 2022 and year 2023.

# %%
df = pd.read_csv('hdb_price_prediction.csv')

# TODO: Enter your code here

# Filtering data based on the year
train_df = df[df['year'] <= 2019]
validation_df = df[df['year'] == 2020]
test_df = df[df['year'] == 2021]

# Sanity Check: Get unique values 
train_unique_years = ', '.join(map(str, train_df['year'].unique()))
validation_unique_years = ', '.join(map(str, validation_df['year'].unique()))
test_unique_years = ', '.join(map(str, test_df['year'].unique()))

# Sanity Check: Print the formatted unique values
print(f"Unique years in train_df: {train_unique_years}")
print(f"Unique years in validation_df: {validation_unique_years}")
print(f"Unique years in test_df: {test_unique_years}")
# Out:
# Unique years in train_df: 2017, 2018, 2019
# Unique years in validation_df: 2020
# Unique years in test_df: 2021

# %% [markdown]
# > Refer to the documentation of **PyTorch Tabular** and perform the following tasks: https://pytorch-tabular.readthedocs.io/en/latest/#usage
# - Use **[DataConfig](https://pytorch-tabular.readthedocs.io/en/latest/data/)** to define the target variable, as well as the names of the continuous and categorical variables.
# - Use **[TrainerConfig](https://pytorch-tabular.readthedocs.io/en/latest/training/)** to automatically tune the learning rate. Set batch_size to be 1024 and set max_epoch as 50.
# - Use **[CategoryEmbeddingModelConfig](https://pytorch-tabular.readthedocs.io/en/latest/models/#category-embedding-model)** to create a feedforward neural network with 1 hidden layer containing 50 neurons.
# - Use **[OptimizerConfig](https://pytorch-tabular.readthedocs.io/en/latest/optimizer/)** to choose Adam optimiser. There is no need to set the learning rate (since it will be tuned automatically) nor scheduler.
# - Use **[TabularModel](https://pytorch-tabular.readthedocs.io/en/latest/tabular_model/)** to initialise the model and put all the configs together.

# %%
# TODO: Enter your code here

# 1. Define the DataConfig
data_config = DataConfig(
    target=['resale_price'], 
    continuous_cols=['dist_to_nearest_stn', 'dist_to_dhoby', 'degree_centrality', 'eigenvector_centrality', 'remaining_lease_years', 'floor_area_sqm'],
    categorical_cols=['month', 'town', 'flat_model_type', 'storey_range']
)

# 2. Define the TrainerConfig
trainer_config = TrainerConfig(
    auto_lr_find=True, 
    batch_size=1024, 
    max_epochs=50, 
)

# 3. Define the CategoryEmbeddingModelConfig
model_config = CategoryEmbeddingModelConfig(
    task="regression",
    layers="50"  # One hidden layer with 50 neurons.
)

# 4. Create the OptimizerConfig
optimizer_config = OptimizerConfig(optimizer="Adam")

# 5. Create the TabularModel
model = TabularModel(
    data_config=data_config,
    model_config=model_config,
    optimizer_config=optimizer_config,
    trainer_config=trainer_config,
)

# 6. Train the model
warnings.filterwarnings("ignore")
model.fit(train=train_df, validation=validation_df, seed = SEED)

# 7. Evaluate the model on the test dataset and store the results
result = model.evaluate(test_df)

# 8. Print the evaluation results
print(result)

# 9. Calculate the Root Mean Square Error (RMSE) from the test results
rmse = math.sqrt(result[0]['test_mean_squared_error'])

# 10. Print the RMSE value
print(f"RMSE: {round(rmse,4)}")

# 11. Get predictions from the machine learning model for the test dataset
pred_df = model.predict(test_df)

# 12. Extract the actual and predicted values from the dataframes
actual_values = test_df['resale_price'].values  
predicted_values = pred_df["resale_price_prediction"].values  

# 13. Calculate the coefficient of determination (R²) between actual and predicted values
r2 = r2_score(actual_values, predicted_values)

# 14. Print the R² value, a measure of the model's goodness of fit
print(f"R²: {round(r2,4)}")
# Out:
# 2023-10-09 17:20:05,154 - {pytorch_tabular.tabular_model:105} - INFO - Experiment Tracking is turned off
# Global seed set to 42
# 2023-10-09 17:20:05,217 - {pytorch_tabular.tabular_model:473} - INFO - Preparing the DataLoaders
# 2023-10-09 17:20:05,225 - {pytorch_tabular.tabular_datamodule:290} - INFO - Setting up the datamodule for regression task
# 2023-10-09 17:20:05,422 - {pytorch_tabular.tabular_model:521} - INFO - Preparing the Model: CategoryEmbeddingModel
# 2023-10-09 17:20:05,517 - {pytorch_tabular.tabular_model:268} - INFO - Preparing the Trainer
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 2023-10-09 17:20:05,570 - {pytorch_tabular.tabular_model:573} - INFO - Auto LR Find Started
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Learning rate set to 0.5754399373371567
# Restoring states from the checkpoint path at c:\Users\Wei Kang\Desktop\Individual Assignment\.lr_find_125b9528-71d3-49ec-9a5b-3a7a87d208b7.ckpt
# Restored all states from the checkpoint file at c:\Users\Wei Kang\Desktop\Individual Assignment\.lr_find_125b9528-71d3-49ec-9a5b-3a7a87d208b7.ckpt
# 2023-10-09 17:20:11,813 - {pytorch_tabular.tabular_model:575} - INFO - Suggested LR: 0.5754399373371567. For plot and detailed analysis, use `find_learning_rate` method.
# 2023-10-09 17:20:11,814 - {pytorch_tabular.tabular_model:582} - INFO - Training Started
# ┏━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃   ┃ Name             ┃ Type                      ┃ Params ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 0 │ _backbone        │ CategoryEmbeddingBackbone │  2.9 K │
# │ 1 │ _embedding_layer │ Embedding1dLayer          │  1.5 K │
# │ 2 │ head             │ LinearHead                │     51 │
# │ 3 │ loss             │ MSELoss                   │      0 │
# └───┴──────────────────┴───────────────────────────┴────────┘
# Trainable params: 4.5 K
# Non-trainable params: 0
# Total params: 4.5 K
# Total estimated model params size (MB): 0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2023-10-09 17:20:51,993 - {pytorch_tabular.tabular_model:584} - INFO - Training the model completed
# 2023-10-09 17:20:51,995 - {pytorch_tabular.tabular_model:1258} - INFO - Loading the best model
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │       5882418176.0        │
# │  test_mean_squared_error  │       5882418176.0        │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# [{'test_loss': 5882418176.0, 'test_mean_squared_error': 5882418176.0}]
# RMSE: 76696.9242
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# R²: 0.7776

# %% [markdown]
# > Report the test RMSE error and the test R2 value that you obtained.

# %% [markdown]
# # Test Results
#
# | Metric         | Value (4 d.p.) |
# |----------------|---------------:|
# | Test RMSE Error| 76696.9242     |
# | Test R² Value  | 0.7776         |

# %% [markdown]
# > Print out the corresponding rows in the dataframe for the top 25 test samples with the largest errors. Identify a trend in these poor predictions and suggest a way to reduce these errors.

# %%
# TODO: Enter your code here

# Step 1: Compute residuals by subtracting predicted resale prices from actual resale prices
pred_df['residuals'] = pred_df['resale_price_prediction'] - test_df['resale_price']

# Step 2: Sort the dataframe by the absolute value of residuals in descending order
pred_df['abs_residuals'] = pred_df['residuals'].abs()
sorted_df = pred_df.sort_values(by='abs_residuals', ascending=False)

# Step 3: Drop unnecessary columns to focus on the main columns
sorted_df.drop(columns=['residuals', 'abs_residuals', 'resale_price_prediction', 'full_address', 'nearest_stn', 'year'], inplace=True)

# Step 4: Get the top 25 samples with the largest errors
top_25_largest_errors = sorted_df.head(25)

# Step 5: Display the results for the top 25 largest errors
display(top_25_largest_errors)

# Step 6: Further exploration of data for the top 25 samples with largest errors:
# Compute mean and median for 'dist_to_dhoby', 'floor_area_sqm', 'remaining_lease_years', count of '3 ROOM' flats, and 'resale_price'
print("For Top 25 Largest Errors:", end='\n\n')
print("Mean 'dist_to_dhoby':", top_25_largest_errors['dist_to_dhoby'].mean())
print("Median 'dist_to_dhoby':", top_25_largest_errors['dist_to_dhoby'].median())

print("Mean 'floor_area_sqm':", top_25_largest_errors['floor_area_sqm'].mean())
print("Median 'floor_area_sqm':", top_25_largest_errors['floor_area_sqm'].median())

print("Mean 'remaining_lease_years':", top_25_largest_errors['remaining_lease_years'].mean())
print("Median 'remaining_lease_years':", top_25_largest_errors['remaining_lease_years'].median())

print("Number of '3 ROOM' flats:", top_25_largest_errors['flat_model_type'].str.contains('3 ROOM').sum())

print("Mean 'resale_price':", top_25_largest_errors['resale_price'].mean())
print("Median 'resale_price':", top_25_largest_errors['resale_price'].median())

# Step 7: Get the top 25 samples with the smallest errors
top_25_smallest_errors = sorted_df.tail(25)

# Step 8: Display the results for the top 25 smallest errors
display(top_25_smallest_errors)

# Step 9: Further exploration of data for the top 25 samples with smallest errors:
# Compute mean and median for 'dist_to_dhoby', 'floor_area_sqm', 'remaining_lease_years', count of '3 ROOM' flats, and 'resale_price'
print("For Top 25 Smallest Errors:", end='\n\n')
print("Mean 'dist_to_dhoby':", top_25_smallest_errors['dist_to_dhoby'].mean())
print("Median 'dist_to_dhoby':", top_25_smallest_errors['dist_to_dhoby'].median())

print("Mean 'floor_area_sqm':", top_25_smallest_errors['floor_area_sqm'].mean())
print("Median 'floor_area_sqm':", top_25_smallest_errors['floor_area_sqm'].median())

print("Mean 'remaining_lease_years':", top_25_smallest_errors['remaining_lease_years'].mean())
print("Median 'remaining_lease_years':", top_25_smallest_errors['remaining_lease_years'].median())

print("Number of '3 ROOM' flats:", top_25_smallest_errors['flat_model_type'].str.contains('3 ROOM').sum())

print("Mean 'resale_price':", top_25_smallest_errors['resale_price'].mean())
print("Median 'resale_price':", top_25_smallest_errors['resale_price'].median())
# Out:
#         month          town  dist_to_nearest_stn  dist_to_dhoby  \
# 92405      11   BUKIT MERAH             0.581977       2.309477
# 90957       6   BUKIT BATOK             1.292540      10.763777
# 112128     12      TAMPINES             0.370873      12.479752
# 90608      12        BISHAN             0.776182       6.297489
# 106192     12    QUEENSTOWN             0.658035       3.807573
# 91871       6   BUKIT MERAH             0.693391       2.058774
# 93825       8  CENTRAL AREA             0.451637       2.594828
# 92504      12   BUKIT MERAH             0.468378       2.365532
# 105695      6    QUEENSTOWN             0.745596       3.720593
# 90432       8        BISHAN             0.827889       6.370404
# 92299      10   BUKIT MERAH             0.490926       2.278805
# 92442      11   BUKIT MERAH             0.686789       2.664024
# 93895      11  CENTRAL AREA             0.490378       2.630876
# 105699      6    QUEENSTOWN             0.745596       3.720593
# 88081       8    ANG MO KIO             0.860056       7.263401
# 106057     10    QUEENSTOWN             0.584731       3.882019
# 90521      10        BISHAN             0.947205       6.663943
# 92340      10   BUKIT MERAH             0.451387       2.128424
# 91694       4   BUKIT MERAH             0.481551       2.262574
# 98379      12       HOUGANG             0.899849       8.828235
# 92226       9   BUKIT MERAH             0.586629       2.932814
# 105468      3    QUEENSTOWN             0.701852       3.763948
# 92533      12   BUKIT MERAH             0.656363       1.982722
# 105966      9    QUEENSTOWN             0.745596       3.720593
# 92066       8   BUKIT MERAH             0.538563       2.345844
#
#         degree_centrality  eigenvector_centrality  \
# 92405            0.016807                0.047782
# 90957            0.016807                0.000217
# 112128           0.033613                0.000229
# 90608            0.033613                0.015854
# 106192           0.016807                0.008342
# 91871            0.016807                0.047782
# 93825            0.016807                0.103876
# 92504            0.016807                0.047782
# 105695           0.016807                0.008342
# 90432            0.033613                0.015854
# 92299            0.016807                0.047782
# 92442            0.016807                0.047782
# 93895            0.016807                0.103876
# 105699           0.016807                0.008342
# 88081            0.016807                0.006243
# 106057           0.016807                0.008342
# 90521            0.033613                0.015854
# 92340            0.016807                0.047782
# 91694            0.016807                0.047782
# 98379            0.016807                0.001507
# 92226            0.016807                0.047782
# 105468           0.016807                0.008342
# 92533            0.016807                0.047782
# 105966           0.016807                0.008342
# 92066            0.016807                0.047782
#
#                        flat_model_type  remaining_lease_years  floor_area_sqm  \
# 92405                 3 ROOM, Standard              50.166667            88.0
# 90957             EXECUTIVE, Apartment              75.583333           144.0
# 112128           EXECUTIVE, Maisonette              61.750000           148.0
# 90608                     5 ROOM, DBSS              88.833333           120.0
# 106192  4 ROOM, Premium Apartment Loft              93.333333           109.0
# 91871                 3 ROOM, Standard              50.583333            88.0
# 93825            5 ROOM, Adjoined flat              54.583333           118.0
# 92504                 3 ROOM, Standard              50.166667            88.0
# 105695  4 ROOM, Premium Apartment Loft              93.916667            97.0
# 90432                     5 ROOM, DBSS              88.916667           120.0
# 92299                 3 ROOM, Standard              50.333333            88.0
# 92442                 5 ROOM, Improved              90.333333           113.0
# 93895            5 ROOM, Adjoined flat              54.250000           139.0
# 105699  4 ROOM, Premium Apartment Loft              93.916667           109.0
# 88081                 5 ROOM, Improved              90.166667           121.0
# 106057  4 ROOM, Premium Apartment Loft              93.500000            97.0
# 90521                 5 ROOM, Improved              69.583333           121.0
# 92340                 5 ROOM, Improved              90.750000           114.0
# 91694                 3 ROOM, Standard              50.833333            88.0
# 98379             EXECUTIVE, Apartment              63.666667           142.0
# 92226                 5 ROOM, Improved              96.750000           113.0
# 105468  4 ROOM, Premium Apartment Loft              94.166667            95.0
# 92533                 5 ROOM, Improved              78.083333           115.0
# 105966  4 ROOM, Premium Apartment Loft              93.666667            97.0
# 92066                 3 ROOM, Standard              50.500000            77.0
#
#        storey_range  resale_price
# 92405      01 TO 03      780000.0
# 90957      10 TO 12      968000.0
# 112128     01 TO 03      998000.0
# 90608      37 TO 39     1360000.0
# 106192     04 TO 06      968000.0
# 91871      01 TO 03      680888.0
# 93825      16 TO 18      938000.0
# 92504      01 TO 03      695000.0
# 105695     07 TO 09      930000.0
# 90432      25 TO 27     1280000.0
# 92299      01 TO 03      690000.0
# 92442      16 TO 18     1165000.0
# 93895      07 TO 09      958000.0
# 105699     31 TO 33     1032888.0
# 88081      28 TO 30     1100000.0
# 106057     13 TO 15      958000.0
# 90521      07 TO 09      988000.0
# 92340      34 TO 36     1245000.0
# 91694      01 TO 03      680000.0
# 98379      04 TO 06      873000.0
# 92226      28 TO 30     1220000.0
# 105468     10 TO 12      920000.0
# 92533      28 TO 30     1130000.0
# 105966     25 TO 27      968800.0
# 92066      01 TO 03      628000.0
# For Top 25 Largest Errors:
#
# Mean 'dist_to_dhoby': 4.39348055137666
# Median 'dist_to_dhoby': 3.720593002068167
# Mean 'floor_area_sqm': 109.96
# Median 'floor_area_sqm': 113.0
# Mean 'remaining_lease_years': 74.73333333333333
# Median 'remaining_lease_years': 78.08333333333333
# Number of '3 ROOM' flats: 6
# Mean 'resale_price': 966183.04
# Median 'resale_price': 968000.0
#         month             town  dist_to_nearest_stn  dist_to_dhoby  \
# 98512       3      JURONG EAST             1.318285      12.291372
# 88682       2            BEDOK             0.562867       7.523270
# 92233      10      BUKIT MERAH             0.782082       3.170640
# 109494      1        SERANGOON             1.667455       8.644621
# 108114      7         SENGKANG             0.447635      11.958252
# 91749       5      BUKIT MERAH             1.002651       3.845544
# 88973       5            BEDOK             0.386846       8.410227
# 101243     12  KALLANG/WHAMPOA             0.757741       2.647546
# 106718      1         SENGKANG             1.333543      12.125693
# 112376      4        TOA PAYOH             1.099275       4.446539
# 96604       8          GEYLANG             0.372043       5.690937
# 113145      1        WOODLANDS             0.363490      16.855191
# 87396       1       ANG MO KIO             1.057895       7.653196
# 105332      2       QUEENSTOWN             0.439838       4.028808
# 105713      7       QUEENSTOWN             0.340391       5.086448
# 110236      2         TAMPINES             0.579172      11.884380
# 105982     10       QUEENSTOWN             0.445263       4.839831
# 87730       5       ANG MO KIO             1.060207       8.705741
# 92691       2    BUKIT PANJANG             1.588947      12.655432
# 100585      3  KALLANG/WHAMPOA             0.438751       2.195773
# 91822       6      BUKIT MERAH             0.114837       5.045128
# 96173       1          GEYLANG             0.335062       5.260871
# 110286      2         TAMPINES             0.877621      13.743954
# 93680       1     CENTRAL AREA             0.288820       1.612202
# 99104       2      JURONG WEST             0.712540      14.483501
#
#         degree_centrality  eigenvector_centrality  \
# 98512            0.025210                0.000550
# 88682            0.016807                0.001743
# 92233            0.016807                0.047782
# 109494           0.016807                0.003825
# 108114           0.016807                0.000233
# 91749            0.016807                0.047665
# 88973            0.016807                0.001743
# 101243           0.016807                0.053004
# 106718           0.016807                0.000233
# 112376           0.016807                0.017995
# 96604            0.033613                0.011178
# 113145           0.016807                0.000024
# 87396            0.016807                0.006243
# 105332           0.016807                0.008342
# 105713           0.016807                0.005350
# 110236           0.033613                0.000229
# 105982           0.016807                0.008342
# 87730            0.016807                0.002459
# 92691            0.008403                0.000070
# 100585           0.016807                0.118015
# 91822            0.016807                0.018783
# 96173            0.016807                0.004897
# 110286           0.016807                0.000127
# 93680            0.033613                0.155969
# 99104            0.016807                0.000085
#
#                      flat_model_type  remaining_lease_years  floor_area_sqm  \
# 98512                4 ROOM, Model A              94.666667            92.0
# 88682           EXECUTIVE, Apartment              71.833333           143.0
# 92233               3 ROOM, Standard              47.333333            63.0
# 109494              5 ROOM, Improved              75.583333           121.0
# 108114              5 ROOM, Improved              78.000000           116.0
# 91749               4 ROOM, Improved              54.000000            82.0
# 88973             3 ROOM, Simplified              64.833333            64.0
# 101243              3 ROOM, Improved              57.666667            66.0
# 106718               3 ROOM, Model A              95.416667            68.0
# 112376              3 ROOM, Improved              48.416667            66.0
# 96604               3 ROOM, Standard              44.500000            60.0
# 113145         EXECUTIVE, Maisonette              66.833333           149.0
# 87396         3 ROOM, New Generation              58.083333            75.0
# 105332     3 ROOM, Premium Apartment              94.500000            65.0
# 105713              3 ROOM, Standard              44.583333            60.0
# 110236               4 ROOM, Model A              62.500000           104.0
# 105982              3 ROOM, Improved              47.333333            66.0
# 87730         3 ROOM, New Generation              59.000000            68.0
# 92691   EXECUTIVE, Premium Apartment              80.500000           130.0
# 100585              3 ROOM, Improved              57.500000            68.0
# 91822               2 ROOM, Improved              53.666667            45.0
# 96173               3 ROOM, Standard              47.000000            56.0
# 110286          EXECUTIVE, Apartment              71.916667           147.0
# 93680               3 ROOM, Improved              58.666667            60.0
# 99104                3 ROOM, Model A              90.166667            67.0
#
#        storey_range  resale_price
# 98512      22 TO 24      525000.0
# 88682      01 TO 03      713000.0
# 92233      04 TO 06      268000.0
# 109494     01 TO 03      490000.0
# 108114     13 TO 15      490000.0
# 91749      07 TO 09      400000.0
# 88973      01 TO 03      305000.0
# 101243     10 TO 12      307000.0
# 106718     04 TO 06      330000.0
# 112376     04 TO 06      240000.0
# 96604      04 TO 06      250000.0
# 113145     10 TO 12      605000.0
# 87396      10 TO 12      306000.0
# 105332     25 TO 27      646888.0
# 105713     10 TO 12      310000.0
# 110236     10 TO 12      460000.0
# 105982     07 TO 09      325000.0
# 87730      01 TO 03      260000.0
# 92691      07 TO 09      485000.0
# 100585     07 TO 09      333000.0
# 91822      04 TO 06      238800.0
# 96173      04 TO 06      230000.0
# 110286     04 TO 06      610000.0
# 93680      10 TO 12      426000.0
# 99104      07 TO 09      325000.0
# For Top 25 Smallest Errors:
#
# Mean 'dist_to_dhoby': 7.792203830376139
# Median 'dist_to_dhoby': 7.523270252583895
# Mean 'floor_area_sqm': 84.04
# Median 'floor_area_sqm': 68.0
# Mean 'remaining_lease_years': 64.98
# Median 'remaining_lease_years': 59.0
# Number of '3 ROOM' flats: 15
# Mean 'resale_price': 395147.52
# Median 'resale_price': 330000.0

# %% [markdown]
# ## Observed Trend
#
# ### Model Underperformance for Premium Houses in Central Locations
#
# The primary trend we've discerned is that our model ***struggles to accurately predict the resale prices of houses that are more expensive and located in central areas***. This observation is supported by the following data insights:
#
# - **Distance to Dhoby Ghaut (dist_to_dhoby)**
#   - Mean for Largest Errors: `4.39 km`
#   - Mean for Smallest Errors: `7.79 km` <br/><br/>
#   > First, it's observed that the distance to Dhoby Ghaut Station (dist_to_dhoby) tends to be smaller for the records with larger prediction errors. Specifically, the mean distance for these samples is approximately 4.39 km, compared to 7.79 km for those with smaller errors. This suggests that the model is less adept at predicting resale prices for flats closer to Dhoby Ghaut.
#
# - **Floor Area (floor_area_sqm)**
#   - Mean for Largest Errors: `109.96 sqm`
#   - Mean for Smallest Errors: `84.04 sqm` <br/><br/>
#   > Secondly, the floor area (floor_area_sqm) of flats also demonstrates a pattern: those with larger errors have a higher mean floor area of 109.96 sqm, as opposed to 84.04 sqm for those with smaller errors. This discrepancy suggests that the model may not be effectively capturing the impact of floor area on resale price.
#
# - **Flat Type ('3 ROOM')**
#   - Largest Errors: `6 out of 25`
#   - Smallest Errors: `15 out of 25` <br/><br/>
#   > Thirdly, a higher concentration of '3 ROOM' flats appears in the bottom 25 rows with smaller errors, constituting 15 out of 25 samples. In contrast, only 6 out of the top 25 rows with the largest errors are '3 ROOM' flats.
#
# - **Remaining Lease Years (remaining_lease_years)**
#   - Mean for Largest Errors: `74.73 years`
#   - Mean for Smallest Errors: `64.98 years` <br/><br/>
#   > Lastly, the remaining lease years of flats also demonstrates a pattern: those with larger errors have a higher mean remaining lease year of 74.73 years, compared to 64.98 years for those with smaller errors. This discrepancy suggests that the model may not be effectively capturing the impact of remaining lease years on resale price.
#
# - **Resale Price**
#   - Mean for Resale Price for Largest Errors: `$966,183.04`
#   - Mean for Resale Price for Smallest Errors: `$395,147.52` <br/><br/>
#   > The resale price in the smallest errors cases is also markedly lower, indicating that the model performs better at predicting lower-valued properties.
#
# ## Recommendations for Model Improvement
#
# 1. **Feature Transformation for Distance to Central Location**
#   - Firstly, we can consider applying logarithmic or polynomial transformations on `dist_to_dhoby` to capture its nonlinear impact on resale prices.
#
# 2. **Incorporate Interaction Terms**
#   - Secondly, we can introduce interaction terms for `floor_area_sqm` with features like town or flat type, capturing compounded effects of size and location/type on pricing.
#
# 3. **Enhance Model Complexity and Architecture**
#   - Current Architecture:
#     - Single hidden layer with 50 neurons
#     - Trainer Config: max_epochs=50, batch_size=1024
#     - Optimizer: Adam
#   - Thirdly, in the context of the PyTorch Tabular model, adjusting the trainer configurations such as max_epochs and batch_size could also be considered. A smaller batch_size might provide a more accurate estimation of the gradient, whereas increasing max_epochs may provide the model more time to converge to a better solution. Additionally, experimenting with different optimizers like RMSprop or SGD could provide different optimization characteristics that may be more suitable for the data distribution at hand. These trainer and optimizer configurations should be carefully tuned and validated to see which combination yields the most accurate predictions.
#
# 4. **Regularization**:
#   - Fourthly, we can choose to incorporate either L1 or L2 regularization to further prevent overfitting on top of techniques like Dropout Layers and Early Stopping to help the model generalize better to unseen data of resale flats.
#
# 5. **Data Augmentation**
#   - Lastly, for better accuracy with premium properties, we can also consider data augmentation techniques, such as synthetic data generation for expensive houses, to refine predictions.
